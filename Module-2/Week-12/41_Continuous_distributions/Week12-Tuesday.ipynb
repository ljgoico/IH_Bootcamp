# %% [markdown]
# ## Continuous Distributions
# ### Uniform

# %% [markdown]
# #### Standard Uniform Distribution in Python example:

# %%
import numpy as np
from scipy.stats import uniform
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(1, 1)
x = np.linspace(0,1, 100)
# Code here
y = uniform.pdf(x)
ax.plot(x, y)

# %% [markdown]
# #### Uniform Distribution between a and b

# %%
fig, ax = plt.subplots(1, 1)
a=1
b=3
x = np.linspace(a,b, 100)
y = uniform.pdf(x,a,b)
# Code here

ax.plot(x, y)

# %% [markdown]
# ### Normal

# %%
import math
from scipy.stats import norm
a = norm(0,math.sqrt(9))
print(a.pdf(6))

fig, ax = plt.subplots(1, 1)
b=3
x = np.linspace(-3,3, 100)
y = norm.pdf(x)
# Code here

ax.plot(x, y)
# Out:
# 0.017996988837729353

# %%
import math
from scipy.stats import norm
a = norm(0,math.sqrt(9))
print(a.pdf(6))

fig, ax = plt.subplots(1, 1)
b=3
x = np.linspace(-100,100, 100)
y = norm(1,16).pdf(x)
# Code here

ax.plot(x, y)
# Out:
# 0.017996988837729353

# %% [markdown]
# ### Exponential distribution

# %%
from scipy.stats import expon

# %%
print(expon.pdf(4))
# Out:
# 0.01831563888873418

# %%
x = np.linspace(0,10,100)

fig,ax = plt.subplots(1,1)
y = expon(4).pdf(x)
ax.plot(x,y)
