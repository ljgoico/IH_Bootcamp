# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
livestock = pd.read_csv("Registre_d_explotacions_ramaderes.csv")

# %%
livestock.head()
# Out:
#   Marca oficial       Codi REGA           Nom Explotació   Adreça Explotació  \
# 0        0010AA  ES250010030750  CASA JOLIU - JORDI GASA         MASIA JOLIU
# 1        0010AA  ES250010030750  CASA JOLIU - JORDI GASA         MASIA JOLIU
# 2        0010AB  ES250010031100             CASA GONELLA             BOIXOLS
# 3        0010AC  ES250010031700         SORT DE L'AGUSTÍ  ABELLA DE LA CONCA
# 4        0010AD  ES250010031744            CAL MASCARELL  ABELLA DE LA CONCA
#
#    C. Postal Servei Territorial Província        Comarca            Municipi  \
# 0      25651          ST Lleida    Lleida  Pallars Jussà  Abella de la Conca
# 1      25651          ST Lleida    Lleida  Pallars Jussà  Abella de la Conca
# 2      25651          ST Lleida    Lleida  Pallars Jussà  Abella de la Conca
# 3      25651          ST Lleida    Lleida  Pallars Jussà  Abella de la Conca
# 4      25651          ST Lleida    Lleida  Pallars Jussà  Abella de la Conca
#
# ...

# %%
livestock.shape
# Out:
# (25367, 29)

# %%
livestock

# %%
livestock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25367 entries, 0 to 25366
# Data columns (total 29 columns):
# Marca oficial               25367 non-null object
# Codi REGA                   25367 non-null object
# Nom Explotació              25367 non-null object
# Adreça Explotació           25367 non-null object
# C. Postal                   25367 non-null int64
# Servei Territorial          25367 non-null object
# Província                   25367 non-null object
# Comarca                     25367 non-null object
# Municipi                    25367 non-null object
# COOR X                      25346 non-null float64
# COOR Y                      25346 non-null float64
# LONGITUD                    25346 non-null float64
# LATITUD                     25346 non-null float64
# Tipus explotació            25367 non-null object
# Espècie                     25367 non-null object
# Integradora                 0 non-null float64
# Classificació zootècnica    25367 non-null object
# ...

# %%
pivotprovincia = livestock.pivot_table(index = ['Província'], aggfunc=['count'])

# %%
pivotprovincia
# Out:
#                       count                                              \
#           Adreça Explotació C. Postal COOR X COOR Y Cap Altres Cap Cria
# Província
# Barcelona              7570      7570   7560   7560       7141     7138
# Girona                 5069      5069   5064   5064       4848     4847
# Lleida                 9098      9098   9095   9095       8695     8692
# Tarragona              3630      3630   3627   3627       3245     3245
#
#                                                                       \
#           Cap Engreix Cap Estant Cap Femelles Cap Mascles Cap Recria
# Província
# Barcelona        7138        371         7138        7138          0
# Girona           4847        167         4847        4847          0
# Lleida           8692        345         8692        8692          0
# Tarragona        3245        338         3245        3245          0
#
#                                                                        \
# ...

# %%
pivotespecie = livestock.pivot_table(index = ['Espècie'], aggfunc=['count'])

# %%
pivotespecie
# Out:
#                                     count                                     \
#                         Adreça Explotació C. Postal COOR X COOR Y Cap Altres
# Espècie
# Abelles                              1221      1221   1218   1218          0
# Alpaques                                3         3      3      3          3
# Anguila                                 3         3      3      3          3
# Aus diferents de corral                 3         3      3      3          3
# Boví                                 5100      5100   5100   5100       5059
# Cabrum                               1503      1503   1501   1501       1469
# Camells                                 1         1      1      1          1
# Cargols                                65        65     65     65         65
# Carpes                                  1         1      1      1          1
# Cignes                                  1         1      1      1          1
# ...
